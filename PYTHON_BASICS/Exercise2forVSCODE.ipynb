# %%
# #Create a folder PythonBasics. Inside it create separate file for each questions
# #Normal human body temperature in 98.6 °F. Convert it to Celsius. (F = 1.8 * C + 32)
F = 98.6 
C = (F - 32)/1.8
print(int(C))

# Calculate simple interest for Rs. 50,000 at rate 6.5% p.a for 4 years. (SI = PTR/100)
P = 50000
T = 4
R = 6.5
SI = P*T*R/100
print (SI)

# Calculate area & perimeter of circle with diameter 12 cm. (Area = πr², P = 2πr)
import math
d = 12
r = d/2
Area = math.pi* r**2
P = 2* math.pi* r
print(Area)
print(P)
# Calculate the total seconds in 3 hours, 20 minutes and 45 seconds.

total_seconds1 = 3*60*60
total_seconds2 = 20*60
total_seconds3 = 45
total= (total_seconds1+ total_seconds2+ total_seconds3)
print(total)

hours = 3
minutes = 20
seconds = 45
total_seconds = (hours* 3600)+ (minutes*60)+ seconds
print(total_seconds)

# Calculate the average of 5 subjects where marks are: 78, 85, 62, 90 and 88.
A = [78, 85, 62, 90, 88]
total = sum(A)
n = len(A)
print(total/n) 


# Convert the distance of 15 kilometers to miles. (1 km = 0.621371 miles)
km = 15
miles = km * 0.621371 
print(miles)
print(f"the result is {miles}")


# Calculate the BMI for a person with weight 70 kg and height 1.75 m. (BMI = wt / ht²)
weight = 70
height = 1.75
BMI = weight / height**2
print(f"The BMI is {BMI}")
print(f"BMI:{BMI:.2f}")

# Calculate the compound interest for amount Rs. 50,000 at rate 6.5% p.a compounded annually for 4 years. (CI = P(1 + r/n)^(nt) - P)
P = 50000
r = 6.5
t = 4
n = 1
CI = P*(1 + r/n)**(n*t) - P
print(f"the compound interest is {CI}")
# Out:
# 36
# 13000.0
# 113.09733552923255
# 37.69911184307752
# 12045
# 12045
# 80.6
# 9.320565
# the result is 9.320565
# The BMI is 22.857142857142858
# BMI:22.86
# the compound interest is 158153125.0
